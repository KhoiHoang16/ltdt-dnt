# %% [markdown]
# # BUỔI 7: CÂY KHUNG NHỎ NHẤT (MST)
#
# Tổng hợp 5 bài tập về thuật toán tìm cây khung nhỏ nhất

# %% [markdown]
# ## Bài 1: Tìm trọng số cây khung nhỏ nhất (Kruskal)

# %%
# %%writefile BAI1.inp
# 5 7
# 1 2 4
# 1 3 2
# 2 3 1
# 2 4 5
# 3 4 8
# 3 5 9
# 4 5 3

# %%
# !g++ -std=c++17 -O2 -o BAI1.exe BAI1.cpp
# !BAI1.exe <  BAI1.inp

# %% [markdown]
# ## Bài 2: Tìm cây khung nhỏ nhất và in các cạnh

# %%
# %%writefile BAI2.inp
# 6 9
# 1 2 4
# 1 3 2
# 2 3 1
# 2 4 5
# 3 4 8
# 3 5 9
# 4 5 3
# 4 6 7
# 5 6 6

# %%
# !g++ -std=c++17 -O2 -o BAI2.exe BAI2.cpp
# !BAI2.exe

# %% [markdown]
# ## Bài 3: Kiểm tra liên thông và tìm MST

# %%
# %%writefile BAI3.inp
# 5 4
# 1 2 3
# 2 3 4
# 3 4 5
# 1 5 2

# %%
# !g++ -std=c++17 -O2 -o BAI3.exe BAI3.cpp
# !BAI3.exe

# %% [markdown]
# ## Bài 4: Tìm MST với cạnh bắt buộc

# %%
# %%writefile BAI4.inp
# 5 7 2
# 1 2 4
# 1 3 2
# 2 3 1
# 2 4 5
# 3 4 8
# 3 5 9
# 4 5 3
# 2 3
# 4 5

# %%
# !g++ -std=c++17 -O2 -o BAI4.exe BAI4.cpp
# !BAI4.exe

# %% [markdown]
# ## Bài 5: Tìm MST bằng thuật toán Prim

# %%
# %%writefile BAI5.inp
# 5 7
# 1 2 4
# 1 3 2
# 2 3 1
# 2 4 5
# 3 4 8
# 3 5 9
# 4 5 3

# %%
# !g++ -std=c++17 -O2 -o BAI5.exe BAI5.cpp
# !BAI5.exe < BAI5.inp
