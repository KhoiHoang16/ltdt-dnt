# %% [markdown]
# ## Bài 1:

# %%
# %%writefile DIJKSTRA.INP
# 6 7 1 4
# 1 2 1
# 1 6 10
# 2 3 2
# 3 4 20
# 3 6 3
# 6 5 4
# 5 4 5
# Out:
# Overwriting DIJKSTRA.INP

# %%
# !g++ -std=c++17 -O2 -o DIJKSTRA.exe DIJKSTRA.CPP
# !DIJKSTRA.exe < DIJKSTRA.INP
# Out:
# 6 15
# 1 2 3 6 5 4

# %% [markdown]
# ## Bài 2:

# %%
# %%writefile NGANNHATTRUNGGIAN.INP
# 6 7 1 4 3
# 1 2 1
# 1 6 10
# 2 3 2
# 3 4 20
# 3 6 3
# 6 5 4
# 5 4 5
# Out:
# Overwriting NGANNHATTRUNGGIAN.INP

# %%
# !g++ -std=c++17 -O2 -o NGANNHATTRUNGGIAN.exe NganNhatTrungGian.cpp
# !NGANNHATTRUNGGIAN.exe < NGANNHATTRUNGGIAN.INP
# Out:
# 6 15
# 1 2 3 6 5 4

# %% [markdown]
# ## Bài 3:

# %%
# %%writefile FLOYD.INP
# 5 6
# 1 2 5
# 1 4 9
# 1 5 1
# 2 3 2
# 3 4 7
# 4 5 2
# Out:
# Overwriting FLOYD.INP

# %%
# !g++ -std=c++17 -O2 -o FLOYD.exe BAI3_Floyd.cpp
# !FLOYD.exe < FLOYD.INP
# Out:
# 0 5 7 3 1
# 5 0 2 8 6
# 7 2 0 7 8
# 3 8 7 0 2
# 1 6 8 2 0

# %% [markdown]
# ## Bài 4:

# %%
# %%writefile DIJKSTRA_PQ.INP
# 6 7 1 4
# 1 2 1
# 1 6 10
# 2 3 2
# 3 4 20
# 3 6 3
# 6 5 4
# 5 4 5
# Out:
# Overwriting DIJKSTRA_PQ.INP

# %%
# !g++ -std=c++17 -O2 -o DIJKSTRA_PQ.exe BAI4_DijkstraPriorityQueue.cpp
# !DIJKSTRA_PQ.exe < DIJKSTRA_PQ.INP
# Out:
# 6 15
# 1 2 3 6 5 4
