# %% [markdown]
# ## Bài 1:

# %%
# %%writefile CIRCLE.INP
# 1 4 4
# 0 0 5
# 0 5 1
# 3 0 5
# 10 0 10
# Out:
# Overwriting CIRCLE.INP

# %%
# !g++ -std=c++17 -O2 -o CIRCLE.exe CIRCLE.cpp
# !CIRCLE.exe < CIRCLE.INP
# Out:
# 1
# 0 2
# 1 0
# 4

# %% [markdown]
# ## Bài 2:

# %%
# %%writefile MINTABLE.INP
# 3 4 1 1 3 4
# 1 2 3 4
# 0 5 1 1
# 3 0 2 1
# Out:
# Overwriting MINTABLE.INP

# %%
# !g++ -std=c++17 -O2 -o MINTABLE.exe MINTABLE.cpp
# !MINTABLE.exe < MINTABLE.INP
# Out:
# 1
# 7
# 1 1
# 1 2
# 1 3
# 2 3
# 2 4
# 3 4
